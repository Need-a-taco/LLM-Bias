# %%
import sys
from pathlib import Path

import pandas as pd

VIZ_ROOT = Path("..").resolve()
sys.path.insert(0, str(VIZ_ROOT))
from yes_no_pie import plot_yes_no_pie

# %%
DATA = VIZ_ROOT / "data" / "papers.csv"
df = pd.read_csv(DATA)
df.columns

# %%
HERE = Path(".").resolve()
yes_n = (df["Has Debiasing"] == "Yes").sum()
no_n = (df["Has Debiasing"] == "No").sum()
plot_yes_no_pie(yes_n, no_n, HERE / "has_debiasing.svg")
