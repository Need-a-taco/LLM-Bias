# %%
import pandas as pd
from collections import Counter, defaultdict
import re
import matplotlib.pyplot as plt
import math

# %%
df = pd.read_csv("papers.csv")
df.columns
# Out:
# Index(['Title', 'Database ', 'Year', 'Month', 'Journal / Conference',
#        'Paper Type\n(Experiment on Existing Models / Experiment on New Models / Benchmark or Dataset)',
#        'Data source\n(Subject)',
#        'Data Country (source)\n(Specific country / NA)',
#        'Data domain\n(EHR / Bio-med / Generated / Other)',
#        'Data language\n(the original lang of data source)',
#        'Data Availability', 'Data Details', 'Size',
#        'Number of Prompts\nIf Applicable', 'Topic', ' Note',
#        'Race / Ethnic Bias', 'Language Bias', 'Age Bias', 'Gender',
#        'Other Bias', 'LGBTQ+', 'Disability', 'Evaluated LLMs',
#        'Reference Standard \n(Human / Model / System / Physician)',
#        'Patient Inclusion\n(Yes / No)', 'Has Debiasing',
#        'Debias - Focus\n(Data/Train/Inference)', 'Debias-details'],
#       dtype='str')

# %% [markdown]
# Focus on statistics related to data access.

# %%
print(df["Data Availability"].unique().tolist())

print(f"")
# Out:
# ['Open Source (I was able to download MedQA from Hugging Face, and Synthea is an open source tool according to the paper), Private (CBHS is private according to the paper)', 'Open Source:Prompts provided in paper', 'Open Source', 'Regulated', 'Regulated, Open Source', nan, "Couldn't find", 'Provided', 'Outdated', 'Open Source, Regulated', "Couldn't Find", 'Unclear, will need help ', 'Unclear, will need help', "Couldn't Find, not Super clear", 'Open Source, Needs a deeper dive', 'PAPILA iand HAM10000 are publically accessible, but MIMIC-CXR is regulated.', 'Unclear', 'Yes', ' Open Source', "Couldn't found", 'Regulated (Need to request)', 'Regulated (Supplementary data provided; raw ratings available upon request)', 'Regulated (link to the data used); Prompts provided in paper', 'Provided in table 1', 'Prompts provided in paper (was able to download directly from paper)', 'randomly selected 10 cases from PubMed Central’s dataset', 'Regulated Data', 'Study Algorithm ', 'Regulated Data, 
# ...
